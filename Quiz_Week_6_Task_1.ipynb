# %% [markdown]
# <a href="https://colab.research.google.com/github/Indu2002-se/ML/blob/main/Quiz_Week_6_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**Import Libraries**

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ##**Load the Dataset**

# %%
df = pd.read_csv("/content/Mobile_Price_Classification-220531-204702.csv")
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# ##**Separate Features and Labels**

# %%
X = df.drop('price_range', axis=1)
y = df['price_range']

# %% [markdown]
# ##**Split Dataset (75% Train, 25% Test)**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %% [markdown]
# ##**Feature Scaling**

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ##B**uild ANN Model**

# %%
model = Sequential()

model.add(Dense(8, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ##**Compile the Model**

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ##**Train the Model**

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.5127 - loss: 0.7892 - val_accuracy: 0.5600 - val_loss: 0.7117
# Epoch 2/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5302 - loss: 0.7399 - val_accuracy: 0.5800 - val_loss: 0.6792
# Epoch 3/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5735 - loss: 0.6923 - val_accuracy: 0.5800 - val_loss: 0.6588
# Epoch 4/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5889 - loss: 0.6680 - val_accuracy: 0.5840 - val_loss: 0.6447
# Epoch 5/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5815 - loss: 0.6631 - val_accuracy: 0.6060 - val_loss: 0.6358
# Epoch 6/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6273 - loss: 0.6339 - val_accuracy: 0.6260 - val_loss: 0.6272
# Epoch 7/100
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6146 - loss: 0.6393 - val_accuracy: 0.6300 - val_loss: 0.6209
# Epoch 8/100
# ...

# %% [markdown]
# ##**Evaluate the Model**

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9219 - loss: 0.2050
# Test Accuracy: 0.8999999761581421

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy}")
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9219 - loss: 0.2050
# Test Accuracy: 0.8999999761581421

# %% [markdown]
# ##**Save Model Weights**

# %%
model.save_weights("mobile_price_weights.weights.h5")
print("Weights saved successfully!")
# Out:
# Weights saved successfully!
